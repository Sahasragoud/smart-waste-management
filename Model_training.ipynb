# %% [markdown]
# <a href="https://colab.research.google.com/github/Sahasragoud/smart-waste-management/blob/add-waste-model/Model_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os, sys, json, itertools, numpy as np, tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt

print("TensorFlow:", tf.__version__)
# Point this to your dataset root (edit if not running in Colab)
DATA_DIR = "dataset"  # e.g., "/content/dataset" in Colab or your local path
IMG_SIZE = (224, 224)
BATCH_SIZE = 32
SEED = 1337
AUTOTUNE = tf.data.AUTOTUNE
# Out:
# TensorFlow: 2.19.0

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
    os.path.join(DATA_DIR, "train"),
    labels="inferred",
    label_mode="int",
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=True,
    seed=SEED,
)
val_ds = tf.keras.utils.image_dataset_from_directory(
    os.path.join(DATA_DIR, "val"),
    labels="inferred",
    label_mode="int",
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False,
)
test_ds = tf.keras.utils.image_dataset_from_directory(
    os.path.join(DATA_DIR, "test"),
    labels="inferred",
    label_mode="int",
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False,
)

class_names = train_ds.class_names
num_classes = len(class_names)
print("Class names and indices:", dict(enumerate(class_names)))
# Out:
# Found 2002 files belonging to 4 classes.
# Found 430 files belonging to 4 classes.
# Found 432 files belonging to 4 classes.
# Class names and indices: {0: 'Hazardous', 1: 'Non-Recyclable', 2: 'Organic', 3: 'Recyclable'}

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DATA_DIR = "/content/drive/MyDrive/datasets/waste_split"

# %%
# Performance options
train_ds = train_ds.prefetch(AUTOTUNE)
val_ds   = val_ds.prefetch(AUTOTUNE)
test_ds  = test_ds.prefetch(AUTOTUNE)

# Data augmentation pipeline
data_augment = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
    layers.RandomContrast(0.1),
], name="augment")

# %%
# Base model (frozen)
base = tf.keras.applications.EfficientNetB0(
    include_top=False, weights="imagenet", input_shape=IMG_SIZE + (3,)
)
base.trainable = False

inputs = keras.Input(shape=IMG_SIZE + (3,))
x = data_augment(inputs)
x = tf.keras.applications.efficientnet.preprocess_input(x)
x = base(x, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.2)(x)
outputs = layers.Dense(num_classes, activation="softmax")(x)
model = keras.Model(inputs, outputs)

model.compile(
    optimizer=keras.optimizers.Adam(1e-3),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ augment (Sequential)            │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb0 (Functional)     │ (None, 7, 7, 1280)     │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 4)              │         5,124 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,054,695 (15.47 MB)
#  Trainable params: 5,124 (20.02 KB)
#  Non-trainable params: 4,049,571 (15.45 MB)

# %%
ckpt_path = "waste_best.keras"
callbacks = [
    keras.callbacks.ModelCheckpoint(ckpt_path, monitor="val_accuracy",
                                    save_best_only=True, mode="max", verbose=1),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=5,
                                  restore_best_weights=True, verbose=1),
    keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.2,
                                      patience=2, verbose=1)
]

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=15,
    callbacks=callbacks
)

# Plot training curves (optional)
plt.figure()
plt.plot(history.history["accuracy"], label="train_acc")
plt.plot(history.history["val_accuracy"], label="val_acc")
plt.legend(); plt.title("Accuracy"); plt.xlabel("epoch"); plt.ylabel("acc")
plt.show()

plt.figure()
plt.plot(history.history["loss"], label="train_loss")
plt.plot(history.history["val_loss"], label="val_loss")
plt.legend(); plt.title("Loss"); plt.xlabel("epoch"); plt.ylabel("loss")
plt.show()
# Out:
# Epoch 1/15
#      39/Unknown 124s 3s/step - accuracy: 0.3652 - loss: 1.3659
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:160: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Epoch 1: val_accuracy improved from -inf to 0.68212, saving model to waste_best.keras
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 155s 4s/step - accuracy: 0.3676 - loss: 1.3624 - val_accuracy: 0.6821 - val_loss: 0.8776 - learning_rate: 0.0010
# Epoch 2/15
# 37/39 ━━━━━━━━━━━━━━━━━━━━ 6s 3s/step - accuracy: 0.6203 - loss: 0.9318
# Epoch 2: val_accuracy improved from 0.68212 to 0.73841, saving model to waste_best.keras
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 148s 4s/step - accuracy: 0.6219 - loss: 0.9291 - val_accuracy: 0.7384 - val_loss: 0.7141 - learning_rate: 0.0010
# Epoch 3/15
# 38/39 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.7023 - loss: 0.8002
# Epoch 3: val_accuracy improved from 0.73841 to 0.75166, saving model to waste_best.keras
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 143s 4s/step - accuracy: 0.7028 - loss: 0.7988 - val_accuracy: 0.7517 - val_loss: 0.6556 - learning_rate: 0.0010
# Epoch 4/15
# 36/39 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - accuracy: 0.7207 - loss: 0.7189
# Epoch 4: val_accuracy improved from 0.75166 to 0.76490, saving model to waste_best.keras
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 140s 4s/step - accuracy: 0.7201 - loss: 0.7200 - val_accuracy: 0.7649 - val_loss: 0.6323 - learning_rate: 0.0010
# Epoch 5/15
# 38/39 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.7265 - loss: 0.7136
# Epoch 5: val_accuracy improved from 0.76490 to 0.77815, saving model to waste_best.keras
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 148s 4s/step - accuracy: 0.7268 - loss: 0.7133 - val_accuracy: 0.7781 - val_loss: 0.6173 - learning_rate: 0.0010
# Epoch 6/15
# 35/39 ━━━━━━━━━━━━━━━━━━━━ 13s 3s/step - accuracy: 0.7341 - loss: 0.6997
# Epoch 6: val_accuracy improved from 0.77815 to 0.78477, saving model to waste_best.keras
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 144s 4s/step - accuracy: 0.7357 - loss: 0.6964 - val_accuracy: 0.7848 - val_loss: 0.6040 - learning_rate: 0.0010
# Epoch 7/15
# 38/39 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.7407 - loss: 0.6826
# Epoch 7: val_accuracy improved from 0.78477 to 0.79801, saving model to waste_best.keras
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 202s 5s/step - accuracy: 0.7409 - loss: 0.6822 - val_accuracy: 0.7980 - val_loss: 0.5907 - learning_rate: 0.0010
# Epoch 8/15
# 37/39 ━━━━━━━━━━━━━━━━━━━━ 6s 3s/step - accuracy: 0.7281 - loss: 0.6708
# Epoch 8: val_accuracy did not improve from 0.79801
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 139s 4s/step - accuracy: 0.7300 - loss: 0.6687 - val_accuracy: 0.7980 - val_loss: 0.5890 - learning_rate: 0.0010
# Epoch 9/15
# 35/39 ━━━━━━━━━━━━━━━━━━━━ 12s 3s/step - accuracy: 0.7724 - loss: 0.6239
# Epoch 9: val_accuracy improved from 0.79801 to 0.80464, saving model to waste_best.keras
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 184s 5s/step - accuracy: 0.7730 - loss: 0.6221 - val_accuracy: 0.8046 - val_loss: 0.5817 - learning_rate: 0.0010
# Epoch 10/15
# 37/39 ━━━━━━━━━━━━━━━━━━━━ 6s 3s/step - accuracy: 0.7833 - loss: 0.5664
# Epoch 10: val_accuracy did not improve from 0.80464
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 150s 4s/step - accuracy: 0.7830 - loss: 0.5677 - val_accuracy: 0.7947 - val_loss: 0.5748 - learning_rate: 0.0010
# Epoch 11/15
# 35/39 ━━━━━━━━━━━━━━━━━━━━ 11s 3s/step - accuracy: 0.7782 - loss: 0.6182
# Epoch 11: val_accuracy did not improve from 0.80464
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 132s 3s/step - accuracy: 0.7776 - loss: 0.6183 - val_accuracy: 0.8013 - val_loss: 0.5648 - learning_rate: 0.0010
# Epoch 12/15
# 38/39 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.7627 - loss: 0.6013
# Epoch 12: val_accuracy did not improve from 0.80464
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 142s 4s/step - accuracy: 0.7630 - loss: 0.6012 - val_accuracy: 0.7815 - val_loss: 0.5718 - learning_rate: 0.0010
# Epoch 13/15
# 34/39 ━━━━━━━━━━━━━━━━━━━━ 15s 3s/step - accuracy: 0.7821 - loss: 0.6037
# Epoch 13: val_accuracy did not improve from 0.80464
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 131s 3s/step - accuracy: 0.7852 - loss: 0.5991 - val_accuracy: 0.7947 - val_loss: 0.5643 - learning_rate: 0.0010
# Epoch 14/15
# 34/39 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - accuracy: 0.7577 - loss: 0.5861
# Epoch 14: val_accuracy did not improve from 0.80464
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 139s 4s/step - accuracy: 0.7595 - loss: 0.5855 - val_accuracy: 0.7649 - val_loss: 0.5679 - learning_rate: 0.0010
# Epoch 15/15
# 37/39 ━━━━━━━━━━━━━━━━━━━━ 6s 3s/step - accuracy: 0.7992 - loss: 0.5552
# Epoch 15: val_accuracy did not improve from 0.80464
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 244s 6s/step - accuracy: 0.7994 - loss: 0.5546 - val_accuracy: 0.7914 - val_loss: 0.5471 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 15.

# %%
# Unfreeze top ~30% of EfficientNet layers
base.trainable = True
for layer in base.layers[: round(0.7 * len(base.layers))]:
    layer.trainable = False

model.compile(
    optimizer=keras.optimizers.Adam(1e-4),  # lower LR
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

history_ft = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=10,
    callbacks=callbacks
)
# Out:
# Epoch 1/10
#      37/Unknown 165s 4s/step - accuracy: 0.6871 - loss: 0.8160
# Epoch 1: val_accuracy did not improve from 0.80464
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 201s 5s/step - accuracy: 0.6879 - loss: 0.8144 - val_accuracy: 0.7781 - val_loss: 0.5792 - learning_rate: 1.0000e-04
# Epoch 2/10
# 38/37 ━━━━━━━━━━━━━━━━━━━━ -3s 4s/step - accuracy: 0.7400 - loss: 0.6588
# Epoch 2: val_accuracy improved from 0.80464 to 0.81126, saving model to waste_best.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 175s 5s/step - accuracy: 0.7407 - loss: 0.6581 - val_accuracy: 0.8113 - val_loss: 0.5407 - learning_rate: 1.0000e-04
# Epoch 3/10
# 35/37 ━━━━━━━━━━━━━━━━━━━━ 7s 4s/step - accuracy: 0.8022 - loss: 0.5125
# Epoch 3: val_accuracy did not improve from 0.81126
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 200s 5s/step - accuracy: 0.8023 - loss: 0.5135 - val_accuracy: 0.8046 - val_loss: 0.5247 - learning_rate: 1.0000e-04
# Epoch 4/10
# 36/37 ━━━━━━━━━━━━━━━━━━━━ 3s 4s/step - accuracy: 0.8175 - loss: 0.5156
# Epoch 4: val_accuracy did not improve from 0.81126
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 161s 4s/step - accuracy: 0.8178 - loss: 0.5151 - val_accuracy: 0.7914 - val_loss: 0.5319 - learning_rate: 1.0000e-04
# Epoch 5/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.8700 - loss: 0.3901
# Epoch 5: val_accuracy did not improve from 0.81126
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 170s 5s/step - accuracy: 0.8693 - loss: 0.3913 - val_accuracy: 0.8013 - val_loss: 0.5124 - learning_rate: 1.0000e-04
# Epoch 6/10
# 36/37 ━━━━━━━━━━━━━━━━━━━━ 3s 4s/step - accuracy: 0.8760 - loss: 0.3856
# Epoch 6: val_accuracy did not improve from 0.81126
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 196s 4s/step - accuracy: 0.8759 - loss: 0.3855 - val_accuracy: 0.8113 - val_loss: 0.4938 - learning_rate: 1.0000e-04
# Epoch 7/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.8872 - loss: 0.3528
# Epoch 7: val_accuracy improved from 0.81126 to 0.83113, saving model to waste_best.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 202s 5s/step - accuracy: 0.8872 - loss: 0.3529 - val_accuracy: 0.8311 - val_loss: 0.4762 - learning_rate: 1.0000e-04
# Epoch 8/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9109 - loss: 0.3004
# Epoch 8: val_accuracy did not improve from 0.83113
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 168s 4s/step - accuracy: 0.9108 - loss: 0.3005 - val_accuracy: 0.8311 - val_loss: 0.4677 - learning_rate: 1.0000e-04
# Epoch 9/10
# 36/37 ━━━━━━━━━━━━━━━━━━━━ 3s 4s/step - accuracy: 0.9035 - loss: 0.2864
# Epoch 9: val_accuracy did not improve from 0.83113
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 164s 4s/step - accuracy: 0.9035 - loss: 0.2865 - val_accuracy: 0.8311 - val_loss: 0.4616 - learning_rate: 1.0000e-04
# Epoch 10/10
# 36/37 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9257 - loss: 0.2529
# Epoch 10: val_accuracy did not improve from 0.83113
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 180s 5s/step - accuracy: 0.9255 - loss: 0.2534 - val_accuracy: 0.8278 - val_loss: 0.4651 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 9.

# %%
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Evaluate
test_loss, test_acc = model.evaluate(test_ds)
print(f"Test Accuracy: {test_acc:.4f}")

# Predictions
y_true = np.concatenate([y for x, y in test_ds], axis=0)
y_pred = np.argmax(model.predict(test_ds), axis=1)

# Classification Report
print(classification_report(y_true, y_pred, target_names=class_names))

# Confusion Matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt="d", xticklabels=class_names, yticklabels=class_names, cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - accuracy: 0.8909 - loss: 0.3863
# Test Accuracy: 0.8523
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:160: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 27s 3s/step
#                 precision    recall  f1-score   support
#
#      Hazardous       0.89      0.95      0.92        44
# Non-Recyclable       0.81      0.85      0.83        52
#        Organic       0.89      0.83      0.86        48
#     Recyclable       0.80      0.75      0.77        32
#
#       accuracy                           0.85       176
#      macro avg       0.85      0.85      0.85       176
#   weighted avg       0.85      0.85      0.85       176

# %%
model.save("waste_classifier.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Recommended (new format)
model.save("waste_classifier.keras")

# %%
import pathlib

bad_files = []
for folder in ["train", "val", "test"]:
    path = pathlib.Path(DATA_DIR) / folder
    for f in path.rglob("*"):
        if f.is_file():
            if not f.suffix.lower() in [".jpg", ".jpeg", ".png", ".bmp", ".gif"]:
                bad_files.append(str(f))

print("Found", len(bad_files), "non-image files")
for f in bad_files[:20]:
    print(f)
# Out:
# Found 0 non-image files

# %%
for f in bad_files:
    os.remove(f)

# %%
from PIL import Image

for folder in ["train", "val", "test"]:
    path = pathlib.Path(DATA_DIR) / folder
    for f in path.rglob("*.jpg"):
        try:
            img = Image.open(f)
            img.verify()
        except Exception as e:
            print("Corrupted:", f, e)
# Out:
# /usr/local/lib/python3.12/dist-packages/PIL/TiffImagePlugin.py:950: UserWarning: Truncated File Read
#   warnings.warn(str(msg))

# %%
from PIL import Image
import pathlib, os

corrupted = []
for folder in ["train", "val", "test"]:
    path = pathlib.Path(DATA_DIR) / folder
    for f in path.rglob("*.*"):
        try:
            img = Image.open(f)
            img.verify()  # check if image is valid
        except Exception as e:
            print("Corrupted:", f, e)
            corrupted.append(f)

print("Total corrupted files:", len(corrupted))

# remove them if you want
for f in corrupted:
    os.remove(f)
# Out:
# Total corrupted files: 0

# %%
import pathlib

tiffs = []
for folder in ["train", "val", "test"]:
    path = pathlib.Path(DATA_DIR) / folder
    for f in path.rglob("*.tif*"):  # catches .tif and .tiff
        tiffs.append(f)

print("Found", len(tiffs), "TIFF files")
for f in tiffs:
    print(f)
# Out:
# Found 0 TIFF files

# %%
train_ds = train_ds.apply(tf.data.experimental.ignore_errors())
val_ds   = val_ds.apply(tf.data.experimental.ignore_errors())
test_ds  = test_ds.apply(tf.data.experimental.ignore_errors())
# Out:
# WARNING:tensorflow:From /tmp/ipython-input-4001086712.py:1: ignore_errors (from tensorflow.python.data.experimental.ops.error_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.ignore_errors` instead.

# %%
train_ds = train_ds.ignore_errors()
val_ds   = val_ds.ignore_errors()
test_ds  = test_ds.ignore_errors()
